# %% [markdown]
# link:
#
# https://www.yes123.com.tw/wk_index/joblist.asp?search_job_t=1&strrec=0&search_key_word=%E5%BE%8C%E7%AB%AF%E5%B7%A5%E7%A8%8B%E5%B8%AB&search_type=job&search_item=1&search_from=index

# %% [markdown]
# ### 測試>單頁抓取全部(title,職缺,浮動視窗資訊)完成後自動換1頁(成功)
# 發現資料不完整
# 發現電話為image 無法取出文字

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
from selenium.webdriver import ActionChains
s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)
driver.get("https://www.yes123.com.tw/wk_index/joblist.asp?search_job_t=1&strrec=0&search_key_word=%E5%BE%8C%E7%AB%AF%E5%B7%A5%E7%A8%8B%E5%B8%AB&search_type=job&search_item=1&search_from=index")
# titles=driver.find_elements_by_class_name("Job_opening_item")#舊寫法

title=driver.find_elements(by=By.CLASS_NAME, value='Job_opening_item')
for titles in title:
    print(titles.text)
    ActionChains(driver).move_to_element(titles).perform()
    time.sleep(1)
    hidepage=driver.find_elements(by=By.CLASS_NAME, value='job_refer_detail.col-4.box_detail_right')   
    time.sleep(1)
    for hidepages in hidepage:        
        print(hidepages.text)
        time.sleep(1)

page=driver.find_element(by=By.CLASS_NAME, value="page-control.next")
ActionChains(driver).click(page).perform()
time.sleep(1)



driver.close()
# Out:
# 07.25
# JAVA後端工程師
# 多必優國際有限公司
# 月薪　35,000 至 85,000元
# 新北市新莊區
# 全職
# #有獎金分紅
# #彈性上下班
# JAVA後端工程師
# 多必優國際有限公司
# 2022 年 7 月 25 日
# 應徵工作
# 徵才說明
# 職務類別：
# 軟體工程師
# 求才人數：
# 1至5人
# 工作地點：
# 新北市新莊區化成路63巷6-3號4樓
# 工作內容：
# 工作內容 1.開發雲端平台、後端架構體系之規劃、設計與優化。 2.整理、分析需求、系統設計和文件撰寫。 3.熟悉 Java、Spring MVC、Spring Boot、Spring Security 4.熟悉 HTTP 協定、Restful 風格 API。 5.會使用 MySQL、MariaDB、PostgreSQL任一資料庫。 6.會使用 maven、git 做專案建置和版本管理。 7.會寫dockerfile，並了解docker基本操作。 相關經歷三年以上 擅長工具：Java、MS SQL、PostgreSQL 工作技能：軟體工程系統開發、軟體程式設計、資料庫程式設計 1.曾使用過MyBatis、lombok、logback、Swagger。 2.有使用過任一雲端服務AWS、GCP、AZURE、…開發系統經驗。 ▍面試條件： 面試須提供過往作品
# 工作性質：
# 全職
# 上班時段：
# 依公司規定
# 薪資待遇：
# 月薪  35,000 至 85,000 元
# 休假制度：
# 週休二日
# 管理人數：
# 不需負擔管理責任
# 工作條件
# 學歷要求：
# 專科以上
# 科系要求：
# 不拘
# 工作經驗：
# 2 年以上
# 企業簡介
# 行業類別：
# 網路/軟體／網路相關
# 電 話：
# 08.10
# 後端工程師
# 開源智造股份有限公司
# 月薪　35,000元以上
# 台北市南港區
# 全職
# 後端工程師
# 開源智造股份有限公司
# 2022 年 8 月 10 日
# 應徵工作
# 徵才說明
# 職務類別：
# 網路程式設計師
# 求才人數：
# 2人
# 工作地點：
# 台北市南港區三重路19之13號(E棟)4樓437室
# 工作內容：
# ...

# %% [markdown]
# ### 測試->每頁點擊(for loop 迴圈失敗)
# - 想法: 把點擊的動作重複變成迴圈

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
from selenium.webdriver import ActionChains
s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)
driver.get("https://www.yes123.com.tw/wk_index/joblist.asp?search_job_t=1&strrec=0&search_key_word=%E5%BE%8C%E7%AB%AF%E5%B7%A5%E7%A8%8B%E5%B8%AB&search_type=job&search_item=1&search_from=index")
# titles=driver.find_elements_by_class_name("Job_opening_item")#舊寫法




page=driver.find_element(by=By.CLASS_NAME, value="page-control.next")
for pages in page:
    ActionChains(driver).click(page).perform()
    time.sleep(1)

   



driver.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 15>()
#       9 # titles=driver.find_elements_by_class_name("Job_opening_item")#舊寫法
#      14 page=driver.find_element(by=By.CLASS_NAME, value="page-control.next")
# ---> 15 for pages in page:
#      16     ActionChains(driver).click(page).perform()
#      17     time.sleep(1)
#
# TypeError: 'WebElement' object is not iterable

# %% [markdown]
# ### 測試->自動換兩頁抓前三筆職缺title內容
# - 目的: 換頁迴圈是否成功

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
from selenium.webdriver import ActionChains
s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)
driver.get("https://www.yes123.com.tw/wk_index/joblist.asp?search_job_t=1&strrec=0&search_key_word=%E5%BE%8C%E7%AB%AF%E5%B7%A5%E7%A8%8B%E5%B8%AB&search_type=job&search_item=1&search_from=index")
# titles=driver.find_elements_by_class_name("Job_opening_item")#舊寫法



apple=driver.find_elements(by=By.CLASS_NAME, value='Job_opening_item')[0:2]# 抓幾頁
for apples in apple :
    title=driver.find_elements(by=By.CLASS_NAME, value='Job_opening_item')[0:3]# 一頁裡面取幾個
    for titles in title :
        print(titles.text)
        time.sleep(1)
    #     ActionChains(driver).move_to_element(titles).perform()
    #     time.sleep(1)
    #     title=driver.find_elements(by=By.CLASS_NAME, value='job_refer_detail.col-4.box_detail_right')
    #     print(titles.text)
    #     time.sleep(1)

    page=driver.find_element(by=By.CLASS_NAME, value="page-control.next")
    ActionChains(driver).click(page).perform()
    time.sleep(1)



driver.close()
# Out:
# 06.11
# 後端工程師
# 開源智造股份有限公司
# 月薪　35,000元以上
# 台北市南港區
# 全職
# 06.08
# 後端工程師
# 豐碩資訊有限公司
# 月薪　30,000 至 40,000元
# 高雄市三民區
# 全職
# 06.13
# 後端工程師(Node.js)_汐止_20537
# 緯創資通股份有限公司
# 薪資面議(經常性薪資達4萬元含以上)
# 新北市汐止區
# 全職
# 05.31
# 🙌 軟件開發工程師 (後端) BackEnd Developer/Software Developer [定期合約]
# 奇資訊保安及網絡有限公司
# 月薪　30,000 至 80,000元
# 台北市中正區
# 全職
# 06.13
# 智慧醫療Java軟體開發工程師(後端/全端)_汐止/高雄_00000
# 緯創資通股份有限公司
# 薪資面議(經常性薪資達4萬元含以上)
# 新北市汐止區
# 全職
# 05.23
# 工程師
# 成正工程有限公司
# 月薪　40,000元以上
# 苗栗縣竹南鎮
# 全職

# %% [markdown]
# ### 測試>取到最後一頁,每頁取一個title,上限30頁
# - 測試最多只能換30頁

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
from selenium.webdriver import ActionChains
s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)
driver.get("https://www.yes123.com.tw/wk_index/joblist.asp?search_job_t=1&strrec=0&search_key_word=%E5%BE%8C%E7%AB%AF%E5%B7%A5%E7%A8%8B%E5%B8%AB&search_type=job&search_item=1&search_from=index")
# titles=driver.find_elements_by_class_name("Job_opening_item")#舊寫法



apple=driver.find_elements(by=By.CLASS_NAME, value='Job_opening_item')# 抓幾頁
for apples in apple :
    time.sleep(1)
    title=driver.find_elements(by=By.CLASS_NAME, value='Job_opening_item')[0:1]# 一頁裡面取幾個
    for titles in title :
        print(titles.text)
        time.sleep(1)
    #     ActionChains(driver).move_to_element(titles).perform()
    #     time.sleep(1)
    #     title=driver.find_elements(by=By.CLASS_NAME, value='job_refer_detail.col-4.box_detail_right')
    #     print(titles.text)
    #     time.sleep(1)

    page=driver.find_element(by=By.CLASS_NAME, value="page-control.next")
    time.sleep(1)
    ActionChains(driver).click(page).perform()
    time.sleep(1)



driver.close()
# Out:
# 06.15
# 後端工程師
# 豐碩資訊有限公司
# 月薪　30,000 至 40,000元
# 高雄市三民區
# 全職
# 05.31
# 🙌 軟件開發工程師 (後端) BackEnd Developer/Software Developer [定期合約]
# 奇資訊保安及網絡有限公司
# 月薪　30,000 至 80,000元
# 台北市中正區
# 全職
# 06.10
# 營造工程師
# 集程工程有限公司
# 月薪　30,000元以上
# 基隆市仁愛區
# 全職
# 06.16
# 保溫(冷)工程人員
# 德辰工程行
# 日薪　1,400 至 2,000元
# 雲林縣麥寮鄉
# 全職
# #免經驗
# #24h必回覆
# 06.15
# 營建材料測試工程師
# 鑫鼎工程有限公司
# 月薪　30,000元
# 新北市淡水區
# 全職
# #免經驗
# 05.20
# 營造工程師
# 勝吉營造工程有限公司
# 月薪　34,000 至 50,000元
# 南投縣埔里鎮
# 全職
# 06.14
# ★誠徵【測量工程師】
# 自強工程顧問有限公司
# 月薪　32,000 至 40,000元
# 新北市中和區
# 全職
# #免經驗
# 06.12
# 工程師
# 立景工程顧問股份有限公司
# 薪資面議(經常性薪資達4萬元含以上)
# 台北市信義區
# 全職
# 06.14
# 工地工程師（新竹）
# 冠凌電氣工程股份有限公司
# 月薪　60,000元以上
# 新竹縣竹北市
# 全職
# 06.10
# 配管工程半技工(需有氬焊佳.無經驗可)
# 澤宇工程行
# 日薪　1,800 至 2,000元
# 台南市安定區
# 全職
# #有獎金分紅
# #免經驗
# 06.15
# 弱電系統工程師(台中)
# 鍵祥資訊工程股份有限公司
# 月薪　30,000 至 40,000元
# 台中市大雅區
# 全職
# 06.15
# 機電現場工程師~電洽0903-188109 陳先生
# 百閎工程行
# 薪資面議(經常性薪資達4萬元含以上)
# 高雄市鼓山區
# 全職
# 06.15
# 弱電系統工程師(新竹)
# 鍵祥資訊工程股份有限公司
# 月薪　30,000 至 45,000元
# 新竹縣竹東鎮
# 全職
# 06.11
# 監造現場工程師(桃園)
# ...

# %% [markdown]
# ### 測試 > 模擬下拉選單點選指定頁數
# - 問題:
# 1. 如何寫成迴圈?
# 2. 如何知道搜尋結果的頁數有幾筆?

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
from selenium.webdriver import ActionChains
from selenium.webdriver.support.ui import Select
s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)
driver.get("https://www.yes123.com.tw/wk_index/joblist.asp?search_job_t=1&strrec=0&search_key_word=%E5%BE%8C%E7%AB%AF%E5%B7%A5%E7%A8%8B%E5%B8%AB&search_type=job&search_item=1&search_from=index")
# titles=driver.find_elements_by_class_name("Job_opening_item")#舊寫法





s1 = Select(driver.find_element(By.ID, 'inputState'))  
time.sleep(1)
select=s1.select_by_index(3)
ActionChains(driver).click(select).perform()
time.sleep(10)
driver.close()
